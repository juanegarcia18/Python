# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\ramah\anaconda2\envs\ipykernel_py3\lib\site-packages (0.25.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in c:\users\ramah\anaconda2\envs\ipykernel_py3\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\ramah\anaconda2\envs\ipykernel_py3\lib\site-packages (from pandas) (1.18.1)
# Requirement already satisfied: pytz>=2017.2 in c:\users\ramah\anaconda2\envs\ipykernel_py3\lib\site-packages (from pandas) (2019.3)
# Requirement already satisfied: six>=1.5 in c:\users\ramah\anaconda2\envs\ipykernel_py3\lib\site-packages (from python-dateutil>=2.6.1->pandas) (1.13.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd #series and dataframe
import numpy as np

# %%
pd.options.display.max_colwidth = 1000 # this allows us to see more columns
pd.options.display.max_rows = 1000 # this allows us to see more rows

# %% [markdown]
# #### Load data

# %% [markdown]
# <a href=http://archive.ics.uci.edu/ml/datasets/Statlog+%28German+Credit+Data%29>Variable description</a>

# %%
# specify the location to the data file
data_file = "German credit data.txt"
# define column names
var_names = [
    "a_status",            #1  Status of existing checking account
    "duration",            #2  Duration in month
    "c_history",           #3  Credit history
    "purpose",             #4  Purpose
    "c_amount",            #5  Credit amount
    "savings",             #6  Savings account/bonds
    "employment",          #7  Present employment since
    "inst_rate",           #8  Installment rate in percentage of disposable income
    "p_status",            #9  Personal status and sex
    "o_debtors",           #10 Other debtors / guarantors
    "residence",           #11 Present residence since
    "property",            #12 Property
    "age",                 #13 Age in years
    "o_inst_plans",        #14 Other isntallment plans
    "housing",             #15 Housing
    "e_credit",            #16 Number of existing credits at this bank
    "job",                 #17 Job
    "ppl_liable",          #18 Number of people being liable to provide maintenance for
    "telephone",           #19 Telephone
    "foreign",             #20 Foreign worker
    "class",               #21 Classification
]

# read from text file
df_data = pd.read_csv(data_file, sep=" ", names=var_names)
df_data
# Out:
#     a_status  duration c_history purpose  c_amount savings employment  \
# 0        A11         6       A34     A43      1169     A65        A75
# 1        A12        48       A32     A43      5951     A61        A73
# 2        A14        12       A34     A46      2096     A61        A74
# 3        A11        42       A32     A42      7882     A61        A74
# 4        A11        24       A33     A40      4870     A61        A73
# ..       ...       ...       ...     ...       ...     ...        ...
# 995      A14        12       A32     A42      1736     A61        A74
# 996      A11        30       A32     A41      3857     A61        A73
# 997      A14        12       A32     A43       804     A61        A75
# 998      A11        45       A32     A43      1845     A61        A73
# 999      A12        45       A34     A41      4576     A62        A71
#
#      inst_rate p_status o_debtors  ...  property age  o_inst_plans housing  \
# 0            4      A93      A101  ...      A121  67          A143    A152
# 1            2      A92      A101  ...      A121  22          A143    A152
# 2            2      A93      A101  ...      A121  49          A143    A152
# 3            2      A93      A103  ...      A122  45          A143    A153
# 4            3      A93      A101  ...      A124  53          A143    A153
# ..         ...      ...       ...  ...       ...  ..           ...     ...
# 995          3      A92      A101  ...      A121  31          A143    A152
# 996          4      A91      A101  ...      A122  40          A143    A152
# 997          4      A93      A101  ...      A123  38          A143    A152
# 998          4      A93      A101  ...      A124  23          A143    A153
# 999          3      A93      A101  ...      A123  27          A143    A152
#
#     e_credit   job ppl_liable  telephone foreign class
# 0          2  A173          1       A192    A201     1
# 1          1  A173          1       A191    A201     2
# 2          1  A172          2       A191    A201     1
# 3          1  A173          2       A191    A201     1
# 4          2  A173          2       A191    A201     2
# ..       ...   ...        ...        ...     ...   ...
# 995        1  A172          1       A191    A201     1
# 996        1  A174          1       A192    A201     1
# 997        1  A173          1       A191    A201     1
# 998        1  A173          1       A192    A201     2
# 999        1  A173          1       A191    A201     1
#
# [1000 rows x 21 columns]

# %%
#The sum of the missing values in each variable
df_data.isnull().sum()
# Out:
# a_status        0
# duration        0
# c_history       0
# purpose         0
# c_amount        0
# savings         0
# employment      0
# inst_rate       0
# p_status        0
# o_debtors       0
# residence       0
# property        0
# age             0
# o_inst_plans    0
# housing         0
# e_credit        0
# job             0
# ppl_liable      0
# telephone       0
# foreign         0
# class           0
# dtype: int64

# %%
#Assign a missing value
df_data['a_status'][0]=np.NaN
df_data['duration'][0]=np.NaN
# Out:
# <ipython-input-4-22dece9d7a54>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['a_status'][0]=np.NaN
# <ipython-input-4-22dece9d7a54>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_data['duration'][0]=np.NaN
# C:\Users\ramah\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
df_data
# Out:
#     a_status  duration c_history purpose  c_amount savings employment  \
# 0        NaN       NaN       A34     A43      1169     A65        A75
# 1        A12      48.0       A32     A43      5951     A61        A73
# 2        A14      12.0       A34     A46      2096     A61        A74
# 3        A11      42.0       A32     A42      7882     A61        A74
# 4        A11      24.0       A33     A40      4870     A61        A73
# ..       ...       ...       ...     ...       ...     ...        ...
# 995      A14      12.0       A32     A42      1736     A61        A74
# 996      A11      30.0       A32     A41      3857     A61        A73
# 997      A14      12.0       A32     A43       804     A61        A75
# 998      A11      45.0       A32     A43      1845     A61        A73
# 999      A12      45.0       A34     A41      4576     A62        A71
#
#      inst_rate p_status o_debtors  ...  property age  o_inst_plans housing  \
# 0            4      A93      A101  ...      A121  67          A143    A152
# 1            2      A92      A101  ...      A121  22          A143    A152
# 2            2      A93      A101  ...      A121  49          A143    A152
# 3            2      A93      A103  ...      A122  45          A143    A153
# 4            3      A93      A101  ...      A124  53          A143    A153
# ..         ...      ...       ...  ...       ...  ..           ...     ...
# 995          3      A92      A101  ...      A121  31          A143    A152
# 996          4      A91      A101  ...      A122  40          A143    A152
# 997          4      A93      A101  ...      A123  38          A143    A152
# 998          4      A93      A101  ...      A124  23          A143    A153
# 999          3      A93      A101  ...      A123  27          A143    A152
#
#     e_credit   job ppl_liable  telephone foreign class
# 0          2  A173          1       A192    A201     1
# 1          1  A173          1       A191    A201     2
# 2          1  A172          2       A191    A201     1
# 3          1  A173          2       A191    A201     1
# 4          2  A173          2       A191    A201     2
# ..       ...   ...        ...        ...     ...   ...
# 995        1  A172          1       A191    A201     1
# 996        1  A174          1       A192    A201     1
# 997        1  A173          1       A191    A201     1
# 998        1  A173          1       A192    A201     2
# 999        1  A173          1       A191    A201     1
#
# [1000 rows x 21 columns]

# %%
#The sum of the missing values in each variable
df_data.isnull().sum()
# Out:
# a_status        1
# duration        1
# c_history       0
# purpose         0
# c_amount        0
# savings         0
# employment      0
# inst_rate       0
# p_status        0
# o_debtors       0
# residence       0
# property        0
# age             0
# o_inst_plans    0
# housing         0
# e_credit        0
# job             0
# ppl_liable      0
# telephone       0
# foreign         0
# class           0
# dtype: int64

# %%
# examine data types
df_data.dtypes
# Out:
# a_status         object
# duration        float64
# c_history        object
# purpose          object
# c_amount          int64
# savings          object
# employment       object
# inst_rate         int64
# p_status         object
# o_debtors        object
# residence         int64
# property         object
# age               int64
# o_inst_plans     object
# housing          object
# e_credit          int64
# job              object
# ppl_liable        int64
# telephone        object
# foreign          object
# class             int64
# dtype: object

# %%
#Frequency Counts of the column
df_data['a_status'].value_counts()
# Out:
# A14    394
# A11    273
# A12    269
# A13     63
# Name: a_status, dtype: int64

# %%
#Getting mean of a column
np.mean(df_data['duration'])
# Out:
# 20.91791791791792

# %%
df_data['duration'].mean()
# Out:
# 20.91791791791792

# %%
#Missing values imputation
from sklearn.base import TransformerMixin

class DataFrameImputer(TransformerMixin):

    def __init__(self):
        """Impute missing values.

        Columns of dtype object are imputed with the most frequent value 
        in column.

        Columns of other types are imputed with mean of column.

        """
    def fit(self, X, y=None):

        self.fill = pd.Series([X[c].value_counts().index[0]
            if X[c].dtype == np.dtype('O') else X[c].mean() for c in X],
            index=X.columns)

        return self

    def transform(self, X, y=None):
        return X.fillna(self.fill)

# %%
df_data = DataFrameImputer().fit_transform(df_data)

# %%
# examine the top 10 rows of the data frame
df_data.head(10)
#df_data
# Out:
#   a_status   duration c_history purpose  c_amount savings employment  \
# 0      A14  20.917918       A34     A43      1169     A65        A75
# 1      A12  48.000000       A32     A43      5951     A61        A73
# 2      A14  12.000000       A34     A46      2096     A61        A74
# 3      A11  42.000000       A32     A42      7882     A61        A74
# 4      A11  24.000000       A33     A40      4870     A61        A73
# 5      A14  36.000000       A32     A46      9055     A65        A73
# 6      A14  24.000000       A32     A42      2835     A63        A75
# 7      A12  36.000000       A32     A41      6948     A61        A73
# 8      A14  12.000000       A32     A43      3059     A64        A74
# 9      A12  30.000000       A34     A40      5234     A61        A71
#
#    inst_rate p_status o_debtors  ...  property age  o_inst_plans housing  \
# 0          4      A93      A101  ...      A121  67          A143    A152
# 1          2      A92      A101  ...      A121  22          A143    A152
# 2          2      A93      A101  ...      A121  49          A143    A152
# 3          2      A93      A103  ...      A122  45          A143    A153
# 4          3      A93      A101  ...      A124  53          A143    A153
# 5          2      A93      A101  ...      A124  35          A143    A153
# 6          3      A93      A101  ...      A122  53          A143    A152
# 7          2      A93      A101  ...      A123  35          A143    A151
# 8          2      A91      A101  ...      A121  61          A143    A152
# 9          4      A94      A101  ...      A123  28          A143    A152
#
#   e_credit   job ppl_liable  telephone foreign class
# 0        2  A173          1       A192    A201     1
# 1        1  A173          1       A191    A201     2
# 2        1  A172          2       A191    A201     1
# 3        1  A173          2       A191    A201     1
# 4        2  A173          2       A191    A201     2
# 5        1  A172          2       A192    A201     1
# 6        1  A173          1       A191    A201     1
# 7        1  A174          1       A192    A201     1
# 8        1  A172          1       A191    A201     1
# 9        2  A174          1       A191    A201     2
#
# [10 rows x 21 columns]

# %%
df_data.columns
# Out:
# Index(['a_status', 'duration', 'c_history', 'purpose', 'c_amount', 'savings',
#        'employment', 'inst_rate', 'p_status', 'o_debtors', 'residence',
#        'property', 'age', 'o_inst_plans', 'housing', 'e_credit', 'job',
#        'ppl_liable', 'telephone', 'foreign', 'class'],
#       dtype='object')

# %%
# produce summary statistics for numerical attributes
# produce value counts for categorical attributes
df_data["class"] = df_data["class"].astype("int32")
for var_name in df_data.columns:
    print("-"*50)
    print(var_name)
    if df_data[var_name].dtype == np.object or np.int32:
        print(df_data[var_name].value_counts())
    if df_data[var_name].dtype == np.int64 or df_data[var_name].dtype == np.float64:
        print(df_data[var_name].describe())
# Out:
# --------------------------------------------------
# a_status
# A14    394
# A11    274
# A12    269
# A13     63
# Name: a_status, dtype: int64
# --------------------------------------------------
# duration
# 24    184
# 12    179
# 18    113
# 36     83
# 6      75
# 15     64
# 9      49
# 48     48
# 30     40
# 21     30
# 10     28
# 27     13
# 60     13
# 42     11
# 11      9
# 20      8
# 8       7
# 9566     1
# 3512     1
# 882      1
# 1391     1
# 1388     1
# 3384     1
# 7476     1
# 1331     1
# 1330     1
# 7472     1
# 1520     1
# 3331     1
# 1323     1
# 1322     1
# 11560    1
# 1318     1
# 15653    1
# 1316     1
# 2108     1
# 1313     1
# 1311     1
# 3357     1
# 1308     1
# 3622     1
# 1301     1
# 1300     1
# 1299     1
# 1297     1
# 3342     1
# 1333     1
# 5433     1
# 2427     1
# 1338     1
# 3430     1
# 1381     1
# 9572     1
# 1377     1
# 1376     1
# 1372     1
# 1371     1
# 3416     1
# 7511     1
# 3414     1
# 1361     1
# 1360     1
# 1358     1
# 1355     1
# 1352     1
# 3399     1
# 3398     1
# 11054    1
# 1346     1
# 1345     1
# 1343     1
# 7485     1
# 3345     1
# 2051     1
# Name: c_amount, dtype: int64
# count     1000.000000
# mean      3271.258000
# std       2822.736876
# min        250.000000
# 25%       1365.500000
# 50%       2319.500000
# 75%       3972.250000
# max      18424.000000
# Name: c_amount, dtype: float64
# --------------------------------------------------
# savings
# A61    603
# A65    183
# A62    103
# A63     63
# A64     48
# Name: savings, dtype: int64
# --------------------------------------------------
# employment
# A73    339
# A75    253
# A74    174
# A72    172
# A71     62
# Name: employment, dtype: int64
# --------------------------------------------------
# inst_rate
# 4    476
# 2    231
# 3    157
# 1    136
# Name: inst_rate, dtype: int64
# count    1000.000000
# mean        2.973000
# std         1.118715
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000
# Name: inst_rate, dtype: float64
# --------------------------------------------------
# p_status
# A93    548
# A92    310
# A94     92
# A91     50
# Name: p_status, dtype: int64
# --------------------------------------------------
# o_debtors
# A101    907
# A103     52
# A102     41
# Name: o_debtors, dtype: int64
# --------------------------------------------------
# residence
# 4    413
# 2    308
# 3    149
# 1    130
# Name: residence, dtype: int64
# count    1000.000000
# mean        2.845000
# std         1.103718
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000
# Name: residence, dtype: float64
# --------------------------------------------------
# property
# A123    332
# A121    282
# A122    232
# A124    154
# Name: property, dtype: int64
# --------------------------------------------------
# age
# 27    51
# 26    50
# 23    48
# 24    44
# 28    43
# 25    41
# 35    40
# 30    40
# 36    39
# 31    38
# 29    37
# 32    34
# 33    33
# 34    32
# 37    29
# 22    27
# 40    25
# 38    24
# 42    22
# 39    21
# 46    18
# 41    17
# 43    17
# 44    17
# 47    17
# 45    15
# 21    14
# 49    14
# 20    14
# 48    12
# 50    12
# 54    10
# 52     9
# 57     9
# 55     8
# 63     8
# 51     8
# 53     7
# 61     7
# 60     6
# 58     5
# 64     5
# 65     5
# 66     5
# 74     4
# 67     3
# 68     3
# 56     3
# 59     3
# 75     2
# 62     2
# 19     2
# 70     1
# Name: age, dtype: int64
# count    1000.000000
# mean       35.546000
# std        11.375469
# min        19.000000
# 25%        27.000000
# 50%        33.000000
# 75%        42.000000
# max        75.000000
# Name: age, dtype: float64
# --------------------------------------------------
# o_inst_plans
# A143    814
# A141    139
# A142     47
# Name: o_inst_plans, dtype: int64
# --------------------------------------------------
# housing
# A152    713
# A151    179
# A153    108
# Name: housing, dtype: int64
# --------------------------------------------------
# e_credit
# 1    633
# 2    333
# 3     28
# 4      6
# Name: e_credit, dtype: int64
# count    1000.000000
# mean        1.407000
# std         0.577654
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         4.000000
# Name: e_credit, dtype: float64
# --------------------------------------------------
# job
# A173    630
# A172    200
# A174    148
# A171     22
# Name: job, dtype: int64
# --------------------------------------------------
# ppl_liable
# 1    845
# 2    155
# Name: ppl_liable, dtype: int64
# count    1000.000000
# mean        1.155000
# std         0.362086
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         2.000000
# Name: ppl_liable, dtype: float64
# --------------------------------------------------
# telephone
# A191    596
# A192    404
# Name: telephone, dtype: int64
# --------------------------------------------------
# foreign
# A201    963
# A202     37
# Name: foreign, dtype: int64
# --------------------------------------------------
# class
# 1    700
# 2    300
# Name: class, dtype: int64

# %%
# encode string values to integers
from sklearn.preprocessing import LabelEncoder

# maintain a dict for string to integer mappings for each column
label_dict = dict()
for var_name in var_names:
    # only map string values
    if df_data[var_name].dtype == np.object:
        le = LabelEncoder()
        # map the string values
        df_data[var_name] = le.fit_transform(df_data[var_name])
        # store the mapping in the dict
        label_dict[var_name] = dict()
        for cls, label in zip(le.classes_, le.transform(le.classes_)):
            label_dict[var_name][label] = cls
label_dict
# Out:
# {'a_status': {0: 'A11', 1: 'A12', 2: 'A13', 3: 'A14'},
#  'c_history': {0: 'A30', 1: 'A31', 2: 'A32', 3: 'A33', 4: 'A34'},
#  'purpose': {0: 'A40',
#   1: 'A41',
#   2: 'A410',
#   3: 'A42',
#   4: 'A43',
#   5: 'A44',
#   6: 'A45',
#   7: 'A46',
#   8: 'A48',
#   9: 'A49'},
#  'savings': {0: 'A61', 1: 'A62', 2: 'A63', 3: 'A64', 4: 'A65'},
#  'employment': {0: 'A71', 1: 'A72', 2: 'A73', 3: 'A74', 4: 'A75'},
#  'p_status': {0: 'A91', 1: 'A92', 2: 'A93', 3: 'A94'},
#  'o_debtors': {0: 'A101', 1: 'A102', 2: 'A103'},
#  'property': {0: 'A121', 1: 'A122', 2: 'A123', 3: 'A124'},
#  'o_inst_plans': {0: 'A141', 1: 'A142', 2: 'A143'},
#  'housing': {0: 'A151', 1: 'A152', 2: 'A153'},
#  'job': {0: 'A171', 1: 'A172', 2: 'A173', 3: 'A174'},
#  'telephone': {0: 'A191', 1: 'A192'},
#  'foreign': {0: 'A201', 1: 'A202'}}

# %%
# examine data types again
df_data.dtypes
# Out:
# a_status        int32
# duration        int64
# c_history       int32
# purpose         int32
# c_amount        int64
# savings         int32
# employment      int32
# inst_rate       int64
# p_status        int32
# o_debtors       int32
# residence       int64
# property        int32
# age             int64
# o_inst_plans    int32
# housing         int32
# e_credit        int64
# job             int32
# ppl_liable      int64
# telephone       int32
# foreign         int32
# class           int64
# dtype: object

# %%
df_data.head(10)
# Out:
#    a_status  duration  c_history  purpose  c_amount  savings  employment  \
# 0         0         6          4        4      1169        4           4
# 1         1        48          2        4      5951        0           2
# 2         3        12          4        7      2096        0           3
# 3         0        42          2        3      7882        0           3
# 4         0        24          3        0      4870        0           2
# 5         3        36          2        7      9055        4           2
# 6         3        24          2        3      2835        2           4
# 7         1        36          2        1      6948        0           2
# 8         3        12          2        4      3059        3           3
# 9         1        30          4        0      5234        0           0
#
#    inst_rate  p_status  o_debtors  ...  property  age  o_inst_plans  housing  \
# 0          4         2          0  ...         0   67             2        1
# 1          2         1          0  ...         0   22             2        1
# 2          2         2          0  ...         0   49             2        1
# 3          2         2          2  ...         1   45             2        2
# 4          3         2          0  ...         3   53             2        2
# 5          2         2          0  ...         3   35             2        2
# 6          3         2          0  ...         1   53             2        1
# 7          2         2          0  ...         2   35             2        0
# 8          2         0          0  ...         0   61             2        1
# 9          4         3          0  ...         2   28             2        1
#
#    e_credit  job  ppl_liable  telephone  foreign  class
# 0         2    2           1          1        0      1
# 1         1    2           1          0        0      2
# 2         1    1           2          0        0      1
# 3         1    2           2          0        0      1
# 4         2    2           2          0        0      2
# 5         1    1           2          1        0      1
# 6         1    2           1          0        0      1
# 7         1    3           1          1        0      1
# 8         1    1           1          0        0      1
# 9         2    3           1          0        0      2
#
# [10 rows x 21 columns]

# %%
# produce some histograms
df_data.hist(figsize=(16, 14));

# %%
# produce summary statistics for numerical attributes
# produce value counts for categorical attributes
df_data["class"] = df_data["class"].astype("int32")
for var_name in var_names:
    print("-"*50)
    print(var_name)
    if df_data[var_name].dtype == np.int32:
        print(df_data[var_name].value_counts())
    if df_data[var_name].dtype == np.int64:
        print(df_data[var_name].describe())
# Out:
# --------------------------------------------------
# a_status
# 3    394
# 0    274
# 1    269
# 2     63
# Name: a_status, dtype: int64
# --------------------------------------------------
# duration
# count    1000.000000
# mean       20.903000
# std        12.058814
# min         4.000000
# 25%        12.000000
# 50%        18.000000
# 75%        24.000000
# max        72.000000
# Name: duration, dtype: float64
# --------------------------------------------------
# c_history
# 2    530
# 4    293
# 3     88
# 1     49
# 0     40
# Name: c_history, dtype: int64
# --------------------------------------------------
# purpose
# 4    280
# 0    234
# 3    181
# 1    103
# 9     97
# 7     50
# 6     22
# 5     12
# 2     12
# 8      9
# Name: purpose, dtype: int64
# --------------------------------------------------
# c_amount
# count     1000.000000
# mean      3271.258000
# std       2822.736876
# min        250.000000
# 25%       1365.500000
# 50%       2319.500000
# 75%       3972.250000
# max      18424.000000
# Name: c_amount, dtype: float64
# --------------------------------------------------
# savings
# 0    603
# 4    183
# 1    103
# 2     63
# 3     48
# Name: savings, dtype: int64
# --------------------------------------------------
# employment
# 2    339
# 4    253
# 3    174
# 1    172
# 0     62
# Name: employment, dtype: int64
# --------------------------------------------------
# inst_rate
# count    1000.000000
# mean        2.973000
# std         1.118715
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000
# Name: inst_rate, dtype: float64
# --------------------------------------------------
# p_status
# 2    548
# 1    310
# 3     92
# 0     50
# Name: p_status, dtype: int64
# --------------------------------------------------
# o_debtors
# 0    907
# 2     52
# 1     41
# Name: o_debtors, dtype: int64
# --------------------------------------------------
# residence
# count    1000.000000
# mean        2.845000
# std         1.103718
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max         4.000000
# Name: residence, dtype: float64
# --------------------------------------------------
# property
# 2    332
# 0    282
# 1    232
# 3    154
# Name: property, dtype: int64
# --------------------------------------------------
# age
# count    1000.000000
# mean       35.546000
# std        11.375469
# min        19.000000
# 25%        27.000000
# 50%        33.000000
# 75%        42.000000
# max        75.000000
# Name: age, dtype: float64
# --------------------------------------------------
# o_inst_plans
# 2    814
# 0    139
# 1     47
# Name: o_inst_plans, dtype: int64
# --------------------------------------------------
# housing
# 1    713
# 0    179
# 2    108
# Name: housing, dtype: int64
# --------------------------------------------------
# e_credit
# count    1000.000000
# mean        1.407000
# std         0.577654
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         4.000000
# Name: e_credit, dtype: float64
# --------------------------------------------------
# job
# 2    630
# 1    200
# 3    148
# 0     22
# Name: job, dtype: int64
# --------------------------------------------------
# ppl_liable
# count    1000.000000
# mean        1.155000
# std         0.362086
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         1.000000
# max         2.000000
# Name: ppl_liable, dtype: float64
# --------------------------------------------------
# telephone
# 0    596
# 1    404
# Name: telephone, dtype: int64
# --------------------------------------------------
# foreign
# 0    963
# 1     37
# Name: foreign, dtype: int64
# --------------------------------------------------
# class
# 1    700
# 2    300
# Name: class, dtype: int64

# %% [markdown]
# #### Split the data into training and testing sets

# %%
from sklearn.model_selection  import train_test_split
attributes = [col for col in var_names if col != "class"]
train_x, test_x, train_y, test_y = train_test_split(df_data[attributes], df_data["class"], test_size=0.3, random_state=123)

# %%
print ("shapes")
print (train_x.shape)
print (test_x.shape)
print (train_y.shape)
print (test_y.shape)

print 

print ("class counts")
print (df_data["class"].value_counts())
print (train_y.value_counts())
print (test_y.value_counts())
# the class counts show that the sampling is roughly stratified
# Out:
# shapes
# (700, 20)
# (300, 20)
# (700,)
# (300,)
# class counts
# 1    700
# 2    300
# Name: class, dtype: int64
# 1    500
# 2    200
# Name: class, dtype: int64
# 1    200
# 2    100
# Name: class, dtype: int64

# %% [markdown]
# #### Decision Tree

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
# train/build model
clf = clf.fit(train_x, train_y)
# make prediction
pred_y = clf.predict(test_x) 
# evaluate the prediction results
from sklearn.metrics import classification_report
for line in classification_report(test_y, pred_y).split("\n"):
    print (line)
# Out:
#               precision    recall  f1-score   support
#
#            1       0.77      0.76      0.76       200
#            2       0.53      0.54      0.53       100
#
#     accuracy                           0.69       300
#    macro avg       0.65      0.65      0.65       300
# weighted avg       0.69      0.69      0.69       300

# %%
from sklearn import tree
clf = tree.DecisionTreeClassifier()
# train model
clf = clf.fit(train_x, train_y)
# make prediction
pred_y = clf.predict(test_x)#pred_y=[1,2,2,1,..........,2]
# evaluate the prediction results

from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score

print ("f1:" + str(f1_score(pred_y, test_y)))
print ("accuracy:" + str(accuracy_score(pred_y, test_y)))
print ("precision:" + str(precision_score(pred_y, test_y)))
print ("recall:" + str(recall_score(pred_y, test_y)))
# Out:
# f1:0.7804878048780488
# accuracy:0.7
# precision:0.8
# recall:0.7619047619047619

# %% [markdown]
# #### Support Vector Machine

# %%
from sklearn.svm import LinearSVC
clf = LinearSVC(random_state=123456)
# train/build model
clf = clf.fit(train_x, train_y)
# make prediction
pred_y = clf.predict(test_x)
# evaluate the prediction results
print ("f1:" + str(f1_score(pred_y, test_y)))
print ("accuracy:" + str(accuracy_score(pred_y, test_y)))
print ("precision:" + str(precision_score(pred_y, test_y)))
print ("recall:" + str(recall_score(pred_y, test_y)))
# Out:
# f1:0.8048289738430584
# accuracy:0.6766666666666666
# precision:1.0
# recall:0.6734006734006734
# C:\Users\ramah\Anaconda2\envs\ipykernel_py3\lib\site-packages\sklearn\svm\base.py:929: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   "the number of iterations.", ConvergenceWarning)

# %% [markdown]
# #### Naive Bayes

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB()
# train model
clf = clf.fit(train_x, train_y)
# make prediction
pred_y = clf.predict(test_x)
# evaluate the prediction results
print ("f1:" + str(f1_score(pred_y, test_y)))
print ("accuracy:" + str(accuracy_score(pred_y, test_y)))
print ("precision:" + str(precision_score(pred_y, test_y)))
print ("recall:" + str(recall_score(pred_y, test_y)))
# Out:
# f1:0.7028423772609821
# accuracy:0.6166666666666667
# precision:0.68
# recall:0.7272727272727273
