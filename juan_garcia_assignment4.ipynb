# %% [markdown]
# #### Imports

# %%
import pandas as pd
import numpy as np
from pandas import read_csv
from sklearn.preprocessing import LabelEncoder
from sklearn.base import TransformerMixin
from sklearn.model_selection  import train_test_split
from sklearn import preprocessing
from sklearn import tree
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.svm import LinearSVC
from sklearn.naive_bayes import MultinomialNB

# %% [markdown]
# #### 1) Load the data set into a pandas dataframe and see how many variables in the data set, and what are their data types.

# %%
pd.options.display.max_colwidth = 1000
pd.options.display.max_rows = 1000

data_file = pd.read_csv("train.csv", nrows=1000)
data_file
# Out:
#                     MachineIdentifier   ProductName EngineVersion  \
# 0    0000028988387b115f69f31a3bf04f09  win8defender   1.1.15100.1
# 1    000007535c3f730efa9ea0b7ef1bd645  win8defender   1.1.14600.4
# 2    000007905a28d863f6d0d597892cd692  win8defender   1.1.15100.1
# 3    00000b11598a75ea8ba1beea8459149f  win8defender   1.1.15100.1
# 4    000014a5f00daa18e76b81417eeb99fc  win8defender   1.1.15100.1
# 5    000016191b897145d069102325cab760  win8defender   1.1.15100.1
# 6    0000161e8abf8d8b89c5ab8787fd712b  win8defender   1.1.15100.1
# 7    000019515bc8f95851aff6de873405e8  win8defender   1.1.15100.1
# 8    00001a027a0ab970c408182df8484fce  win8defender   1.1.15200.1
# 9    00001a18d69bb60bda9779408dcf02ac  win8defender   1.1.15100.1
# 10   00001b3b3cf8c8c079a272ce51031753  win8defender   1.1.15100.1
# 11   00001b924fcc6922321cfadbafd8a91a  win8defender   1.1.15100.1
# 12   00001f26e9e5775277d6231fc6ac9e70  win8defender   1.1.15100.1
# ...

# %%
data_file.dtypes
# Out:
# MachineIdentifier                                     object
# ProductName                                           object
# EngineVersion                                         object
# AppVersion                                            object
# AvSigVersion                                          object
# IsBeta                                                 int64
# RtpStateBitfield                                     float64
# IsSxsPassiveMode                                       int64
# DefaultBrowsersIdentifier                            float64
# AVProductStatesIdentifier                            float64
# AVProductsInstalled                                  float64
# AVProductsEnabled                                    float64
# HasTpm                                                 int64
# CountryIdentifier                                      int64
# CityIdentifier                                       float64
# ...

# %% [markdown]
# #### 2) Provide analysis of the missing value percentage in each variable.

# %%
data_file.isnull().sum()/len(data_file)
# Out:
# MachineIdentifier                                    0.000
# ProductName                                          0.000
# EngineVersion                                        0.000
# AppVersion                                           0.000
# AvSigVersion                                         0.000
# IsBeta                                               0.000
# RtpStateBitfield                                     0.002
# IsSxsPassiveMode                                     0.000
# DefaultBrowsersIdentifier                            0.946
# AVProductStatesIdentifier                            0.003
# AVProductsInstalled                                  0.003
# AVProductsEnabled                                    0.003
# HasTpm                                               0.000
# CountryIdentifier                                    0.000
# CityIdentifier                                       0.045
# OrganizationIdentifier                               0.317
# ...

# %% [markdown]
# #### 3) Show the total number of missing values in all variables

# %%
data_file.isnull().sum()
# Out:
# MachineIdentifier                                      0
# ProductName                                            0
# EngineVersion                                          0
# AppVersion                                             0
# AvSigVersion                                           0
# IsBeta                                                 0
# RtpStateBitfield                                       2
# IsSxsPassiveMode                                       0
# DefaultBrowsersIdentifier                            946
# AVProductStatesIdentifier                              3
# AVProductsInstalled                                    3
# AVProductsEnabled                                      3
# HasTpm                                                 0
# CountryIdentifier                                      0
# CityIdentifier                                        45
# OrganizationIdentifier                               317
# ...

# %% [markdown]
# #### 4) Produce a) summary statistics for numerical attributes b) value counts for categorical attributes (i.e, thier data type is object)

# %%
data_file["HasDetections"] = data_file["HasDetections"].astype("int32")

for index in data_file.columns:
    print("-"*50)
    print(index)
    if data_file[index].dtype == object:
        print(data_file[index].value_counts())
    if data_file[index].dtype == np.int64:
        print(data_file[index].describe())
    if data_file[index].dtype == np.float64:
        print(data_file[index].describe())
# Out:
# --------------------------------------------------
# MachineIdentifier
# 0000028988387b115f69f31a3bf04f09    1
# 0004eb91add58287df74f019e3074e28    1
# 0004d673c672e815d627900e3e1373fb    1
# 0004d7919f16fc92f59ba72fadeea5b1    1
# 0004d833f28dc7c8aafee718e635a536    1
# 0004d8a39ac1fe8d005f75bb9b880cdf    1
# 0004d8fc5637a08fb8b80b2722238110    1
# 0004da8557916e92be7ab85e528b746d    1
# 0004dbaf86cb8c8a8f0dc861a12b34bd    1
# 0004dbda76d407bb623f009318682292    1
# 0004dbdf07a628db78be5dc33d78c21d    1
# 0004dc92789f7c4eb095db413f0304fb    1
# 0004e1e699652ecf6e289349db441fb1    1
# 0004e5164e54a75b7f760809616291d4    1
# 0004e8e6c053373a4ca6b35de2d6a149    1
# 0004f14ff43144db7c69e9fb54be6d7f    1
# 00050b10b7c47f62355f16d6e95697f4    1
# 0004f36dbcf1cb44fd41bc09e2f1f965    1
# 0004f8611c48e5e5235abfafa6ce1541    1
# 0004f90fc5fdaae09ef3efe37b7714b0    1
# 0004fcf94e47caa7b8f2e7ae3547b695    1
# 0004fd634a27b83fa2f997a17a563787    1
# 0004fe7d7b2a1534fe21bb39f8660f80    1
# ...

# %% [markdown]
# #### 5) Do missing value imputation (please review German Credit - updated file posted in Blackboard). Columns of dtype object are imputed with the most frequent value in the column. Columns of other types are imputed with mean of the column.

# %%
class DataFrameImputer(TransformerMixin):

    def __init__(self):
        """Impute missing values.

        Columns of dtype object are imputed with the most frequent value 
        in column.

        Columns of other types are imputed with mean of column.

        """
    def fit(self, X, y=None):

        self.fill = pd.Series([X[c].value_counts().index[0]
            if X[c].dtype == np.dtype('O') else X[c].mean() for c in X],
            index=X.columns)

        return self

    def transform(self, X, y=None):
        return X.fillna(self.fill)

# %%
data_file = DataFrameImputer().fit_transform(data_file)

# %% [markdown]
# #### 6) Show the total number of missing values again in all variables. Now, after missing value imputation, it should be 0

# %%
print("Total numbers of missing value:",data_file.isnull().sum().sum())
# Out:
# Total numbers of missing value: 0

# %% [markdown]
# #### 7) Do string encoding (i.e, encode string values to integers)

# %%
le = preprocessing.LabelEncoder()
for index in data_file.columns:
    if data_file[index].dtype == "O":
        data_file[index] = le.fit_transform(data_file[index])

# %%
data_file.dtypes
# Out:
# MachineIdentifier                                      int32
# ProductName                                            int32
# EngineVersion                                          int32
# AppVersion                                             int32
# AvSigVersion                                           int32
# IsBeta                                                 int64
# RtpStateBitfield                                     float64
# IsSxsPassiveMode                                       int64
# DefaultBrowsersIdentifier                            float64
# AVProductStatesIdentifier                            float64
# AVProductsInstalled                                  float64
# AVProductsEnabled                                    float64
# HasTpm                                                 int64
# CountryIdentifier                                      int64
# CityIdentifier                                       float64
# ...

# %% [markdown]
# Second, modeling:

# %% [markdown]
# #### 8) Split the data into training and testing sets (80-20)

# %%
attributes = [col for col in data_file.columns if col != "HasDetections"]
train_x, test_x, train_y, test_y = train_test_split(data_file[attributes], data_file["HasDetections"], test_size=0.2, random_state=123)

# %%
print ("shapes")
print (train_x.shape)
print (test_x.shape)
print (train_y.shape)
print (test_y.shape)

print 

print ("HasDetections counts")
print (data_file["HasDetections"].value_counts())
print (train_y.value_counts())
print (test_y.value_counts())
# Out:
# shapes
# (800, 82)
# (200, 82)
# (800,)
# (200,)
# HasDetections counts
# 1    512
# 0    488
# Name: HasDetections, dtype: int64
# 1    408
# 0    392
# Name: HasDetections, dtype: int64
# 1    104
# 0     96
# Name: HasDetections, dtype: int64

# %% [markdown]
# #### 9) Build different machine learning models like Decision Tree. Show the performance of the model (f1, accuracy, precision, and recall)

# %% [markdown]
# #### Decision Tree

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(train_x, train_y)
pred_y = clf.predict(test_x) 

from sklearn.metrics import classification_report
for line in classification_report(test_y, pred_y).split("\n"):
    print (line)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.59      0.50      0.54        96
#            1       0.60      0.68      0.64       104
#
#     accuracy                           0.59       200
#    macro avg       0.59      0.59      0.59       200
# weighted avg       0.59      0.59      0.59       200

# %%
clf = tree.DecisionTreeClassifier()
clf = clf.fit(train_x, train_y)
pred_y = clf.predict(test_x)

print ("f1:" + str(f1_score(pred_y, test_y)))
print ("accuracy:" + str(accuracy_score(pred_y, test_y)))
print ("precision:" + str(precision_score(pred_y, test_y)))
print ("recall:" + str(recall_score(pred_y, test_y)))
# Out:
# f1:0.6190476190476191
# accuracy:0.6
# precision:0.625
# recall:0.6132075471698113

# %% [markdown]
# #### Support Vector Machine

# %%
clf = LinearSVC(random_state=123456)
clf = clf.fit(train_x, train_y)
pred_y = clf.predict(test_x)

print ("f1:" + str(f1_score(pred_y, test_y)))
print ("accuracy:" + str(accuracy_score(pred_y, test_y)))
print ("precision:" + str(precision_score(pred_y, test_y)))
print ("recall:" + str(recall_score(pred_y, test_y)))
# Out:
# f1:0.07207207207207209
# accuracy:0.485
# precision:0.038461538461538464
# recall:0.5714285714285714
# c:\Users\juane\.pyenv\pyenv-win\versions\3.10.0\lib\site-packages\sklearn\svm\_base.py:1225: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %% [markdown]
# #### Naive Bayes

# %%
clf = MultinomialNB()
clf = clf.fit(train_x, train_y)
pred_y = clf.predict(test_x)

print ("f1:" + str(f1_score(pred_y, test_y)))
print ("accuracy:" + str(accuracy_score(pred_y, test_y)))
print ("precision:" + str(precision_score(pred_y, test_y)))
print ("recall:" + str(recall_score(pred_y, test_y)))
# Out:
# f1:0.5619834710743802
# accuracy:0.47
# precision:0.6538461538461539
# recall:0.4927536231884058
